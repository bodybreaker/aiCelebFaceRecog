# %%
import tensorflow as tf
from tensorflow import keras


import numpy as np
import matplotlib.pyplot as plt

fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# 픽셀 값의 범위를 나눈다
train_images = train_images / 255.0
test_images = test_images / 255.0


plt.figure(figsize=(10,10))

for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-241d326215e2> in <module>
#       1 import tensorflow as tf
# ----> 2 from tensorflow import keras
#       3
#       4
#       5 import numpy as np
#
# ImportError: cannot import name 'keras' from 'tensorflow' (unknown location)

# %%
# 모델 층 설정

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    
    # 10 개의 노드, 10개의 확률을 반환 하는 층
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 모델 컴파일
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 데이터 학습
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4978 - accuracy: 0.8246
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3744 - accuracy: 0.8655
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3372 - accuracy: 0.8767
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3140 - accuracy: 0.8841
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2942 - accuracy: 0.8921

# %%
# 정확도 평가
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\n테스트 정확도:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.3529 - accuracy: 0.8725
#
# 테스트 정확도: 0.8725000023841858

# %%
# 예측 만들기
predictions = model.predict(test_images)

np.argmax(predictions[0])

test_labels[0]
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# 처음 X 개의 테스트 이미지와 예측 레이블, 진짜 레이블을 출력합니다
# 올바른 예측은 파랑색으로 잘못된 예측은 빨강색으로 나타냅니다
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
plt.show()

# %% [markdown]
# # 꽃 데이터 예측

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib 
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-1-7b74a5b773e9>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
import pathlib

dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url, 
                                   fname='flower_photos', 
                                   untar=True)
data_dir = pathlib.Path(data_dir)
print(data_dir)

data_dir = pathlib.Path('C:/Users/pmw18/Desktop/개발/AICelebFaceRecognizer/test')

print(data_dir)
# Out:
# C:\Users\pmw18\.keras\datasets\flower_photos
# C:\Users\pmw18\Desktop\개발\AICelebFaceRecognizer\test

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)

cls = list(data_dir.glob('*/*.jpg'))
PIL.Image.open(str(cls[1]))
# Out:
# 283
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=237x237 at 0x269403C0D88>

# %%
# 데이터 불러오기
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)


print(val_ds.class_names)
# Out:
# Found 274 files belonging to 11 classes.
# Using 220 files for training.
# Found 274 files belonging to 11 classes.
# Using 54 files for validation.
# ['CL', 'G.NA', 'JAYB', 'JIN', 'Jun.K', 'NC.A', '가인', '강다니엘', '강민경', '강성훈', '강인']

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl


class_names = train_ds.class_names
print(class_names)
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# ['CL', 'G.NA', 'JAYB', 'JIN', 'Jun.K', 'NC.A', '가인', '강다니엘', '강민경', '강성훈', '강인']

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))


AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# 0.0 1.0

# %%
## 훈련하기
num_classes = 11

model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])


model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=100,batch_size=10
    
    
)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 24ms/step - loss: 2.4057 - accuracy: 0.0773 - val_loss: 2.4211 - val_accuracy: 0.0741
# Epoch 2/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3822 - accuracy: 0.1182 - val_loss: 2.4689 - val_accuracy: 0.0741
# Epoch 3/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3684 - accuracy: 0.1227 - val_loss: 2.5040 - val_accuracy: 0.0741
# Epoch 4/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3456 - accuracy: 0.1455 - val_loss: 2.4926 - val_accuracy: 0.0741
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3126 - accuracy: 0.2045 - val_loss: 2.4876 - val_accuracy: 0.2222
# Epoch 6/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2374 - accuracy: 0.2909 - val_loss: 2.4456 - val_accuracy: 0.2407
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0929 - accuracy: 0.3000 - val_loss: 2.2762 - val_accuracy: 0.2037
# Epoch 8/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9106 - accuracy: 0.3455 - val_loss: 2.1513 - val_accuracy: 0.2593
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.7617 - accuracy: 0.4182 - val_loss: 2.0823 - val_accuracy: 0.2593
# Epoch 10/100
# 7/7 [==============================] - 0s 12ms/step - loss: 
# 7/7 [==============================] - ETA: 0s - loss: 2.9864e-04 - accuracy: 1.00 - 0s 11ms/step - loss: 2.7854e-04 - accuracy: 1.0000 - val_loss: 4.2822 - val_accuracy: 0.4259
# Epoch 83/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2.7188e-04 - accuracy: 1.0000 - val_loss: 4.2893 - val_accuracy: 0.4259
# Epoch 84/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.6523e-04 - accuracy: 1.0000 - val_loss: 4.2973 - val_accuracy: 0.4259
# Epoch 85/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.5912e-04 - accuracy: 1.0000 - val_loss: 4.3049 - val_accuracy: 0.4259
# Epoch 86/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.5304e-04 - accuracy: 1.0000 - val_loss: 4.3123 - val_accuracy: 0.4259
# Epoch 87/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.4726e-04 - accuracy: 1.0000 - val_loss: 4.3211 - val_accuracy: 0.4259
# Epoch 88/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.4180e-04 - accuracy: 1.0000 - val_loss: 4.3281 - val_accuracy: 0.4259
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3645e-04 - accuracy: 1.0000 - val_loss: 4.3348 - val_accuracy: 0.4259
# Epoch 90/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3134e-04 - accuracy: 1.0000 - val_loss: 4.3433 - val_accuracy: 0.4259
# Epoch 91/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2631e-04 - accuracy: 1.0000 - val_loss: 4.3503 - val_accuracy: 0.4259
# Epoch 92/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.2162e-04 - accuracy: 1.0000 - val_loss: 4.3582 - val_accuracy: 0.4259
# Epoch 93/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1704e-04 - accuracy: 1.0000 - val_loss: 4.3669 - val_accuracy: 0.4259
# Epoch 94/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1258e-04 - accuracy: 1.0000 - val_loss: 4.3743 - val_accuracy: 0.4259
# Epoch 95/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0841e-04 - accuracy: 1.0000 - val_loss: 4.3811 - val_accuracy: 0.4259
# Epoch 96/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0430e-04 - accuracy: 1.0000 - val_loss: 4.3876 - val_accuracy: 0.4259
# Epoch 97/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0000e-04 - accuracy: 1.0000 - val_loss: 4.3941 - val_accuracy: 0.4259
# Epoch 98/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9619e-04 - accuracy: 1.0000 - val_loss: 4.4011 - val_accuracy: 0.4259
# Epoch 99/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9240e-04 - accuracy: 1.0000 - val_loss: 4.4077 - val_accuracy: 0.4259
# Epoch 100/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8870e-04 - accuracy: 1.0000 - val_loss: 4.4154 - val_accuracy: 0.4259

# %%
import tensorflowjs as tfjs
#tfjs.converters.save_keras_model(model, './test')
model.save('./model/test.h5')
